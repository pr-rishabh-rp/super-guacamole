# %% [markdown]
# ## Importing all the required libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## Retrieve the webpage

# %%
url = "https://www.indiacustomercare.com/s-v-nit-surat-contact-no"

# %% [markdown]
# ## Extracting the actual tables from the webpage

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, "lxml")
tables = soup.find_all("table")

# %% [markdown]
# ### Collecting the data from these tables to properly fit our DataFrame, via the creation of a list of Dictionaries

# %%
for table in tables:
    # Creating a list of Dictionaries

    table_data = []

    rows = table.find_all("tr")
    for row in rows:
        columns = row.find_all("td")
        # print(columns)
        column_data = {}
        for i, column in enumerate(columns):
            # use headers as key
            header = table.find_all("th")[i].text if table.find_all("th") else i
            column_data[header] = column.text.replace("\n", "").replace("   ", "")
            # print(column.text)
        table_data.append(column_data)


    # convert list of dictionaries into pandas DataFrame

    df = pd.DataFrame(table_data)

    # Since the first row in an html table consists purely of headers, first column_data is an empty
    # dictionary, which when appended in the list table_data, gives such a result:

    # [{}, {'Name' : 'Dr. Hitesh. R. Jariwala', 'Designation' : 'Centre In-charge', 'Number'...]

    # This empty dictionary is problematic because when fed into a DataFrame (like df), pandas
    # recognises this as a valid row of the table and fills the data with NaN wherever
    # applicable. So we drop the first row. :)
    df.drop(0, inplace=True)

    display(df)
    print('')
    print('')
# Out:
#                        Name                               Designation  \
# 1  Dr. Hitesh.  R. Jariwala                          Centre In-charge
# 2          Mr. Snehal Vashi  Academic Section,Administrative Building
#
#           Number                                       Email
# 1  0261-2201580   hrj [at] eed [dot] svnit [dot] ac [dot] in
# 2   0261-2201543                                           -
#                           Name  \
# 1   Prof. (Dr.) Anupam  Shukla
# 2              Dr. P. L. Patel
# 3            Dr. Pramod Mathur
# 4              Dr. Sanjay Shah
# 5            Shri. A. C. Patel
# 6             Shri K. K. Singh
# 7             Dr. Deepam Patel
# 8            Shri A. K. Sharma
# 9           Dr. Chirag Vaghela
# 10         Shri Ravindra Kumar
# 11      Shri B. P. Shibasankar
# 12        Shri Dilay A. Parmar
# 13             Dr. Neha Sharma
#
#                                           Designation        Number  \
# 1                                            Director  0261-2201505
# 2                                        Dy. Director             -
# 3                                           Registrar  0261-2201509
# 4                               Chief Medical Officer  0261-2201600
# 5   Senior ScientificOfficer & I/cDy. Registrar(Ac...  0261-2201541
# 6                                Dy. Registrar(Estt.)  0261-2201503
# 7                          Senior Executive Engineer   0261-2201730
# 8                                 Assistant Librarian  0261-2201741
# 9                                         SAS Officer  0261-2201915
# 10                    Asst. Registrar (Posted at MoE)             -
# 11                         Asst. Registrar (Accounts)  0261-2201552
# 12                                  Technical Officer  0261-2201566
# 13                                    Medical Officer  0261-2201700
#
#                                                 Email
# 1               director [at] svnit [dot] ac [dot] in
# 2            dy_director [at] svnit [dot] ac [dot] in
# 3   registrar [at] svnit [dot] ac [dot] inpramodma...
# 4                 doctor [at] svnit [dot] ac [dot] in
# 5                dy_acad [at] svnit [dot] ac [dot] in
# 6                dy_estt [at] svnit [dot] ac [dot] in
# 7                   srec [at] svnit [dot] ac [dot] in
# 8                library [at] svnit [dot] ac [dot] in
# 9                    vca [at] svnit [dot] ac [dot] in
# 10        ravinder [dot] kumar@svnit [at] ac [dot] in
# 11                ar_acc [at] svnit [dot] ac [dot] in
# 12              daparmar [at] svnit [dot] ac [dot] in
# 13      doctornehasharma [at] svnit [dot] ac [dot] in
#                             Name                          Office
# 1                       Director  0261-2201505Res.- 0261-2213119
# 2                                             Res.- 0261-2201515
# 3    Security (Director Bunglow)              Res.- 0261-2201110
# 4                            NaN                             NaN
# 5                     Patel P.L.                    0261-2201504
# ..                           ...                             ...
# 616             IPPBXServer Room                    0261-2201560
# 617             Electrical (SS5)                    0261-2201212
# 618           Telephone Complain                    0261-2201234
# 619                         Fire                    0261-2201100
# 620           Main Gate Security                    0261-2201111
#
# [620 rows x 2 columns]
#                              Name  \
# 1                   Dr. R. V. Rao
# 2             Dr. Mansoor Ahammed
# 3                Dr. A. A. Shaikh
# 4             Dr. Dhiren R. Patel
# 5               Shri. R. P. Gohil
# 6            Dr. Bhavesh N. Gohil
# 7            Dr. Rasika N. Dhavse
# 8              Dr. Sabha Raj Arya
# 9         Dr. Rahul Radhakrishnan
# 10           Dr. Abhilash Mandloi
# 11              Dr. Jitesh Chavda
# 12             Dr. Satyajit Patel
# 13                 Dr. A. K. Jana
# 14           Dr. Abhishek Acharya
# 15            Dr. Urvashi Kaushal
# 16             Dr. Ketan Kuperkar
# 17   Dr. Jammala Venkataramanaiah
# 18           Dr. Ashish Dhamaniya
# 19            Dr. Vishisht Bhaiya
# 20                  Dr. V. N. Lad
# 21                Dr. Y. D. Patil
# 22                Dr. A. V. Doshi
# 23               Shri K. K. Singh
# 24                Dr. Sumit Khare
# 25          Dr. Balu Laxman Parne
#
#                                           Designation        Number  \
# 1                    Prof. Incharge - Central Library  0261-2201775
# 2               Prof. Incharge - Training & Placement  0261-2201850
# 3                       Prof. Incharge -Research Park  0261-2201774
# 4               Prof. Incharge -International Affairs  0261-2201613
# 5   Faculty Incharge - Computing and Networking Fa...  0261-2201617
# 6   Additional Faculty Incharge - Computing and Ne...  0261-2201623
# 7   Faculty Incharge - Gardening & Campus Beautifi...  0261-2201775
# 8   Faculty Incharge - Electrical and Communicatio...  0261-2201693
# 9   Additional FacultyIncharge - Electrical and Co...  0261-2201593
# 10                      Faculty Incharge - Hindi Cell  0261-2201697
# 11  Faculty Incharge - Construction and Maintenanc...  0261-2201880
# 12  Faculty Incharge - Construction and Maintenanc...  0261-2201863
# 13  Faculty Incharge - Housekeeping and Sanitation...  0261-2201650
# 14  Additional Faculty Incharge - Housekeeping and...  0261-2201706
# 15  Additional Faculty Incharge - Training &Placement  0261-2201989
# 16                   Faculty Incharge - Central Store  0261-2201974
# 17        Additional Faculty Incharge - Central Store  0261-2201596
# 18            Faculty Incharge - Security Arrangement  0261-2201857
# 19  Additional Faculty Incharge - Security Arrange...  0261-2201885
# 20              Faculty Incharge - Finance & Accounts  0261-2201655
# 21                       Faculty Incharge - MIS & NAD  0261-2201866
# 22            Faculty Incharge - Fire & Safety System  0261-2201786
# 23                     Officer Incharge - Guest house  0261-2201503
# 24  Additional Incharge - Gardening & CampusBeauti...  0261-2201796
# 25         Faculty Incharge -Public Grievance Portal   0261-2201624
#
#                                                 Email
# 1                 ic_lib [at] svnit [dot] ac [dot] in
# 2                 ic_tnp [at] svnit [dot] ac [dot] in
# 3                                                   -
# 4                                                   -
# 5                 ic_ccc [at] svnit [dot] ac [dot] in
# 6             add_ic_ccc [at] svnit [dot] ac [dot] in
# 7              ic_garden [at] svnit [dot] ac [dot] in
# 8                 ic_ecs [at] svnit [dot] ac [dot] in
# 9                                                   -
# 10                                                  -
# 11                                                  -
# 12                                                  -
# 13  ic_hs [at] svnit [dot] ac [dot] in ,ic_newcrc ...
# 14                                                  -
# 15                                                  -
# 16              ic_store [at] svnit [dot] ac [dot] in
# 17   ic_additional_store [at] svnit [dot] ac [dot] in
# 18           ic_security [at] svnit [dot] ac [dot] in
# 19                                                  -
# 20                ic_acc [at] svnit [dot] ac [dot] in
# 21                ic_mis [at] svnit [dot] ac [dot] in
# 22                                                  -
# 23         ic_guesthouse [at] svnit [dot] ac [dot] in
# 24                                                  -
# 25                                                  -
#                       Name                                        Designation  \
# 1        Dr. Pramod Mathur                                          Registrar
# 2          Dr. N. K. Datta              Asso. Prof. & Head Physical Education
# 3    Prof. Mansoor Ahammed              Prof I/C Training & Placement section
# 4      Dr. Urvashi Kaushal  Additional Faculty Incharge - Training & Place...
# 5         Mr. A. K. Sharma                                Assistant Librarian
# 6      Prof. R. VenkataRao                        Prof. I/C. InstituteLibrary
# 7       Dr. M. Chakraborty    Chairman, Centre for Continuing Education (CCE)
# 8   Dr. M. Mansoor Ahammed                       Prof I/C Training &Placement
# 9      Dr. Urvashi Kaushal            Additional Prof I/CTraining & Placement
# 10   Mrs. Bhargvi Jagirdar             (T & P Section) Administrative officer
#
#                                    Number  \
# 1   0261-2201509, 8987419390 0261-2201508
# 2                              9904003876
# 3                            0261-2201540
# 4                  0261-22017649998218126
# 5                              9624821279
# 6                                       -
# 7                 0261-220161099040 03862
# 8                              9825875162
# 9                              9998218126
# 10                             9825689997
#
#                                                 Email
# 1   registrar [at] svnit [dot] ac [dot] in, pramod...
# 2                    nkd [at] svnit [dot] ac [dot] in
# 3                 ic_tnp [at] svnit [dot] ac [dot] in
# 4                                                   -
# 5                    aks [at] svnit [dot] ac [dot] in
# 6                 ic_lib [at] svnit [dot] ac [dot] in
# 7                                                   -
# 8                 ic_tnp [at] svnit [dot] ac [dot] in
# 9   k [dot] urvashi [at] amhd [dot] svnit [dot] ac...
# 10  tnp [at] svnit [dot] ac [dot] intnpnitsurat [a...
#                                    Name / Designation     Phone No.  \
# 1                                                 NaN           NaN
# 2   D. R. Roy, Associate Professor,Department of P...  0261-2201707
# 3   R. D. Shah,Associate Professor, Mechanical Eng...  0261-2201934
# 4                                                 NaN           NaN
# 5   R. K. Jana, Assistant Professor, Department of...  0261-2201991
# 6   R. Chilipi, Assistant Professor, Department of...  0261-2201592
# 7                                                 NaN           NaN
# 8               Amit C. PatelDy. Registrar (Academic)  0261-2201618
# 9                                                 NaN           NaN
# 10                                                NaN           NaN
# 11                                       Exam Section  0261-2201616
# 12                                       Exam Section  0261-2201616
# 13                                Scholarship Section  0261-2201844
# 14                                Scholarship Section  0261-2201844
# 15                           B. Tech. 1st(UG Section)  0261-2201843
# 16                           B. Tech. 2nd(UG Section)  0261-2201840
# 17                           B. Tech. 3rd(UG Section)  0261-2201839
# 18                           B. Tech. 4th(UG Section)  0261-2201840
# 19                                  M.Sc.(PG Section)  0261-2201842
# 20                                M.Tech.(PG Section)  0261-2201841
# 21                                  Ph.D.(PG Section)  0261-2201512
# 22                                              Ph.D.  0261-2201617
# 23                                                MIS  0261-2201775
#
#                                                 Email
# 1                                                 NaN
# 2             adean_acad [at] svnit [dot] ac [dot] in
# 3            adean1_acad [at] svnit [dot] ac [dot] in
# 4                                                 NaN
# 5         rkj [at] amhd [dot] svnit [dot] ac [dot] in
# 6      rsreddy [at] eed [dot] svnit [dot] ac [dot] in
# 7                                                 NaN
# 8   dy_acad [at] svnit [dot] ac [dot] in, amit [at...
# 9                                                 NaN
# 10                                                NaN
# 11  acad_exam [at] svnit [dot] ac [dot] in,msp [at...
# 12  academic [dot] verification [at] svnit [dot] a...
# 13  scholarship [at] svnit [dot] ac [dot] in, cms ...
# 14  scholarship [at] svnit [dot] ac [dot] in, bkp ...
# 15  acad_btech1 [at] svnit [dot] ac [dot] in, s [d...
# 16           acad_btech2 [at] svnit [dot] ac [dot] in
# 17           acad_btech3 [at] svnit [dot] ac [dot] in
# 18  acad_btech4 [at] svnit [dot] ac [dot] inmina [...
# 19              acad_msc [at] svnit [dot] ac [dot] in
# 20            acad_mtech [at] svnit [dot] ac [dot] in
# 21              acad_phd [at] svnit [dot] ac [dot] in
# 22         dean_acad_phd [at] svnit [dot] ac [dot] in
# 23       mis [dot] surat [at] iitms [dot] co [dot] in
#                       Name          Designation        Number
# 1   Shri. B. P. Sibasankar  Assistant Registrar  0261-2201552
# 2       Shri R. D. Ruparel     Assistant (SG-I)  0261-2201554
# 3     Shri Vinesh R. Patel    Assistant (SG-II)  0261-2201555
#                         Name          Designation                    Number  \
# 1                        NaN                  NaN                       NaN
# 2        Dr. Meghal A. Desai   Head of Department  8780756818 0261-2201641
# 3        Dr. Z. V. P. Murthy      Professor (HAG)  9228275184 0261-2201643
# 4           Dr. P. A. Parikh            Professor   92281354250261-2201644
# 5          Dr. M.Chakraborty            Professor  9904003862 0261-2201646
# ..                       ...                  ...                       ...
# 248     Dr. Himanshu  Pandey  Assistant Professor   8130425223 0261-2201961
# 249       Dr Mithun Karmakar  Assistant Professor   9564242146 0261-2201962
# 250      Dr. Ms Dipika Patel  Assistant Professor   9537411323 0261-2201963
# 251      Dr Vikash KumarOjha  Assistant Professor   9920642686 0261-2201964
# 252  Dr. Sharad Kumar  Yadav  Assistant Professor                6386308130
#
#                                                  Email
# 1                                                  NaN
# 2          hod [at] ched [dot] svnit [dot] ac [dot] in
# 3    zvpm [at] ched [dot] svnit [dot] ac [dot] in z...
# 4          pap [at] ched [dot] svnit [dot] ac [dot] in
# 5    mch [at] ched [dot] svnit [dot] ac [dot] in mo...
# ..                                                 ...
# 248  hp [at] phy [dot] svnit [dot] ac [dot] inhpiit...
# 249  mithun [dot] k [at] phy [dot] svnit [dot] ac [...
# 250  dipikapatel [at] phy [dot] svnit [dot] ac [dot...
# 251  vko [at] phy [dot] svnit [dot] ac [dot] inohja...
# 252                      sharadky [at] gmail [dot] com
#
# [252 rows x 4 columns]
#                   Name                  Designation        Number
# 1    Shri. K. K. Singh  Dy. Registrar Establishment  0261-2201552
# 2  Shri. A. V. Panchal             Assistant (SG-I)  0261-2201554
# 3    Shri. M. C. Vania            Assistant (SG-II)  0261-2201555
# 4    Shri. R. J. Patel             Senior Assistant  0261-2201554
# 5    Shri. K. D. Gamit             Office Attendant  0261-2201554
#                                                Name  \
# 1                                               NaN
# 2                                  Shri K. K. Singh
# 3                                               NaN
# 4                                 Dr. Pramod Mathur
# 5                                               NaN
# 6                Prof. C. D Modhera,Professor, DoCE
# 7           Dr. Ravi Kant,Associate Professor, DoME
# 8                Prof. S. N. Sharma,Professor, DoEE
# 9         Prof. D. C. JinwalaProfessor (HAG), DoCSE
# 10              Prof. V. L. Manekar,Professor, DoCE
# 11        Dr. P. V. Timbadiya,Asso. Professor, DoCE
# 12                                              NaN
# 13                 Prof. Gaurang J. Joshi,Professor
# 14               Prof. Jyotirmay Banerjee,Professor
# 15                    Prof. A. K. Panchal,Professor
# 16               Dr. Piyush N. PatelAsso. Professor
# 17                Dr. Rupa G. Mehta,Asso. Professor
# 18              Dr. Meghal A. Desai,Asso. Professor
# 19               Dr. Dimple V. Shah,Asso. Professor
# 20            Dr. Jayesh M. Dhodiya,Asso. Professor
# 21              Dr. Suresh Kumar K.,Asso. Professor
# 22                                              NaN
# 23                                 Shri K. K. Singh
# 24              Dr. V. N. LadAsso. Professor, DoChE
# 25                               Shri Amit C. Patel
# 26                                   Dr. S. G. Shah
# 27           Dr. S. R. Patel,Asso. Professor, DoChE
# 28         Dr. H. R. Jariwala,Asso. Professor, DoEE
# 29              Prof. V. L. Manekar,Professor, DoCE
# 30    Dr. N. K. DattaAsso. Professor, Physical Edu.
# 31                      Dr. Pramod Mathur,Registrar
# 32             Shri Ajay Sharma,Assistant Librarian
# 33                                              NaN
# 34            Shri K. K. SinghDy. Registrar (Estt.)
# 35      Dr. Rasika N. Dhavse,Asso. Professor, DoEcE
# 36          Dr.Sabha Raj Arya,Asso. Professor, DoEE
# 37  Dr. Abhilash Mandloi,Assistant Professor, DoEcE
# 38      Dr. Jitesh Chavda,Assistant Professor, DoCE
# 39            Dr. A. K. Jana,Asso. Professor, DoChE
# 40            Prof. Mansoor Ahammed,Professor, DoCE
# 41            Dr. A. K. Jana,Asso. Professor, DoChE
# 42    Dr. Rahul Radhekrishnan,Asst. Professor, DoEE
# 43       Dr. R. P. Gohil,Associate Professor, DoCSE
# 44               Prof. A. A. Shaikh,Professor, DoME
# 45                  Prof. R. V. Rao,Professor, DoME
# 46       Dr. Ketan Kuperkar,Assistant Profesor, DoC
# 47        Dr. Ashish Dhamniya,Asso. Professor, DoCE
# 48      Dr. Jayesh M. Dhodiya,Asso. Professor, DoMH
# 49       Prof. Mousami Chakraborty,Professor, DoChE
# 50                                              NaN
# 51                                Dr. Debesh R. Roy
# 52                                   Dr. R. D. Shah
# 53                                 Dr. Sushil Kumar
# 54                                  Dr. Y. D. Patil
# 55                                  Dr. K. D. Yadav
# 56                                  Dr. H. B. Mehta
# 57                              Dr. Sanjay R. Patel
#
#                                           Designation  \
# 1                                                 NaN
# 2             Deputy Registrar(Establishment Section)
# 3                                                 NaN
# 4                                           Registrar
# 5                                                 NaN
# 6                              Dean (Faculty Welfare)
# 7                              Dean (Student Welfare)
# 8                                     Dean (Academic)
# 9                       Dean (Research & Consultancy)
# 10                       Dean (Planning& Development)
# 11                 Dean (Alumni & ResourceGeneration)
# 12                                                NaN
# 13             Department  of Civil Engineering(DoCE)
# 14        Department  of MechanicalEngineering (DoME)
# 15         Department  ofElectrical Engineering(DoEE)
# 16      Department  of ElectronicsEngineering (DoEcE)
# 17  Department  of Computer Science andEngineering...
# 18          Department  of ChemicalEngineering(DoChE)
# 19                       Department of Physics  (DoP)
# 20     Department of Mathematics andHumanities (DoMH)
# 21                     Department of  Chemistry (DoC)
# 22                                                NaN
# 23            Deputy Registrar(Establishment Section)
# 24                  FIC (Finance &  Accounts Section)
# 25            I/C. Deputy Registrar(Academic Section)
# 26                   Chief Medical Officer,Dispensary
# 27      Co-Chairman (Council of Warden)Hostel Section
# 28                          Coordinator,TEQIP Section
# 29                        Dean,Estate & Store Section
# 30  Physical EducationSection(Student Activity Cen...
# 31                                      CPIO,RTI CELL
# 32                                            Library
# 33                                                NaN
# 34                              Institute Guest House
# 35                 Gardening &  Campus Beautification
# 36                 Electrical and CommunicationSystem
# 37                                         Hindi Cell
# 38                        Construction &  Maintenance
# 39                         Housekeeping &  Sanitation
# 40                               Training & Placement
# 41                       New Class Room  Complex(CRC)
# 42                       New Class Room  Complex(CRC)
# 43                        Computing  Network Facility
# 44               Research Park and  Incubation Centre
# 45                                  Institute Library
# 46                                      Central Store
# 47                               Security Arrangement
# 48                     Liaison officer  of SC/ST Cell
# 49      Chairman Center for ContinuingEducation (CCE)
# 50                                                NaN
# 51                              Asso. Dean (Academic)
# 52                              Asso. Dean (Academic)
# 53                      Asso. Dean  (Faculty Welfare)
# 54              Asso. Dean  (Planning & Developement)
# 55          Asso. Dean (Research & Consultancy) (CRP)
# 56          Asso. Dean (Research & Consultancy) (CRP)
# 57                        Asso. Dean(Student Welfare)
#
#                                                Email
# 1                                                 NaN
# 2                dy_estt [at] svnit [dot] ac [dot] in
# 3                                                 NaN
# 4   registrar [at] svnit [dot] ac [dot] in, pramod...
# 5                                                 NaN
# 6                dean_fw [at] svnit [dot] ac [dot] in
# 7                 deansw [at] svnit [dot] ac [dot] in
# 8              dean_acad [at] svnit [dot] ac [dot] in
# 9               dean_rnc [at] svnit [dot] ac [dot] in
# 10               dean_pd [at] svnit [dot] ac [dot] in
# 11              dean_arg [at] svnit [dot] ac [dot] in
# 12                                                NaN
# 13         hod [at] ced [dot] svnit [dot] ac [dot] in
# 14         hod [at] med [dot] svnit [dot] ac [dot] in
# 15         hod [at] eed [dot] svnit [dot] ac [dot] in
# 16        hod [at] eced [dot] svnit [dot] ac [dot] in
# 17        hod [at] coed [dot] svnit [dot] ac [dot] in
# 18        hod [at] ched [dot] svnit [dot] ac [dot] in
# 19         hod [at] phy [dot] svnit [dot] ac [dot] in
# 20        hod [at] amhd [dot] svnit [dot] ac [dot] in
# 21        hod [at] chem [dot] svnit [dot] ac [dot] in
# 22                                                NaN
# 23               dy_estt [at] svnit [dot] ac [dot] in
# 24                dy_acc [at] svnit [dot] ac [dot] in
# 25               dy_acad [at] svnit [dot] ac [dot] in
# 26                doctor [at] svnit [dot] ac [dot] in
# 27        srp [at] ched [dot] svnit [dot] ac [dot] in
# 28                 teqip [at] svnit [dot] ac [dot] in
# 29               dean_pd [at] svnit [dot] ac [dot] in
# 30  nkd [at] svnit [dot] ac [dot] inic_sac [at] sv...
# 31               rticell [at] svnit [dot] ac [dot] in
# 32             librarian [at] svnit [dot] ac [dot] in
# 33                                                NaN
# 34              ic_svpgh [at] svnit [dot] ac [dot] in
# 35             ic_garden [at] svnit [dot] ac [dot] in
# 36         sra [at] eed [dot] svnit [dot] ac [dot] in
# 37        asm [at] eced [dot] svnit [dot] ac [dot] in
# 38         jtc [at] amd [dot] svnit [dot] ac [dot] in
# 39                 ic_hs [at] svnit [dot] ac [dot] in
# 40                ic_tnp [at] svnit [dot] ac [dot] in
# 41        akj [at] ched [dot] svnit [dot] ac [dot] in
# 42  r [dot] rahul [at] eed [dot] svnit [dot] ac [d...
# 43                ic_ccc [at] svnit [dot] ac [dot] in
# 44         aas [at] med [dot] svnit [dot] ac [dot] in
# 45               library [at] svnit [dot] ac [dot] in
# 46              ic_store [at] svnit [dot] ac [dot] in
# 47           ic_security [at] svnit [dot] ac [dot] in
# 48        jmd [at] amhd [dot] svnit [dot] ac [dot] in
# 49             chair_cce [at] svnit [dot] ac [dot] in
# 50                                                NaN
# 51            adean_acad [at] svnit [dot] ac [dot] in
# 52          adean1_acad [at] svnit [dot] ac [dot] in
# 53              adean_fw [at] svnit [dot] ac [dot] in
# 54              adean_pd [at] svnit [dot] ac [dot] in
# 55         adean_rnc-crp [at] svnit [dot] ac [dot] in
# 56         adean_rnc-srp [at] svnit [dot] ac [dot] in
# 57              adean_sw [at] svnit [dot] ac [dot] in
#                                          Dsecription  \
# 1                                              Bank
# 2                                        Post Office
# 3                   Security Control  Room-Main Gate
# 4                                   Security Officer
# 5            Prof-In-Charge,Institute SecuritySystem
# 6  Additional Prof.In-charge, InstituteSecurity S...
#
#                         Number
# 1                 0261-2227125
# 2                 0261-2227591
# 3  0261-2201698 ,0261-2201918
# 4                   9725636938
# 5                   9904003860
# 6                   8849931589
#                                                  Name  \
# 1                                                 NaN
# 2   Dr. S. R. Patel,  Associate Professor,  Depart...
# 3                                                 NaN
# 4                                                 NaN
# 5                                       Bhabha Bhavan
# 6                                       Gajjar Bhavan
# 7                                Mother Teresa Bhavan
# 8                                       Narmad Bhavan
# 9                                        Nehru Bhavan
# 10                                       Raman Bhavan
# 11                                    Sarabhai Bhavan
# 12                            Swami Vivekanand Bhavan
# 13                                      Tagore Bhavan
# 14                      Gajjar Bhavan & Tagore Bhavan
# 15                Mother Teresa Bhavan & Nehru Bhavan
# 16       Sarabhai Bhavan,Raman Bhavan & Narmad Bhavan
# 17            Swami Vivekanand Bhavan & Bhabha Bhavan
#
#                                           Designation        Number  \
# 1                                                 NaN           NaN
# 2   Co-Chairman,  Council of Warden &Associate Dea...  0261-2201612
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# 5   Dr. Rakesh Maurya,  Associate Professor,  Depa...  0261-2201663
# 6   Shri Amit J. Solanki,  Assistant Professor,  D...  0261-2201606
# 7   Dr. Khyati D. Mistry,  Associate Professor,  D...  0261-2201667
# 8   Dr. Bhavesh Gohil,  Assistant Professor,  Depa...  0261-2201771
# 9   Dr. Sabha Raj Arya,  Associate Professor,  Dep...  0261-2201560
# 10  Dr. Manish K Rathod,  Assistant Professor,  De...  0261-2204366
# 11  Dr. Harshit K. Dave,  Associate Professor,  De...  0261-2201988
# 12  Dr. G.C. Jadeja,  Assistant Professor,  Depart...  0261-2201643
# 13  Dr. A. K. Mungray,  Associate Professor,  Depa...  0261-2201716
# 14                                                  -  0261-2201602
# 15                                                  -  0261-2201602
# 16                                                  -  0261-2201602
# 17                                                  -  0261-2201602
#
#                                           Email
# 1                                           NaN
# 2        adean_sw [at] svnit [dot] ac [dot] in,
# 3                                           NaN
# 4                                           NaN
# 5       cw1_bhabha [at] svnit [dot] ac [dot] in
# 6       cw1_gajjar [at] svnit [dot] ac [dot] in
# 7          cw1_mtb [at] svnit [dot] ac [dot] in
# 8       cw1_narmad [at] svnit [dot] ac [dot] in
# 9        cw1_nehru [at] svnit [dot] ac [dot] in
# 10       cw1_raman [at] svnit [dot] ac [dot] in
# 11    cw1_sarabhai [at] svnit [dot] ac [dot] in
# 12         cw1_svb [at] svnit [dot] ac [dot] in
# 13      cw1_tagore [at] svnit [dot] ac [dot] in
# 14  hostel_office1 [at] svnit [dot] ac [dot] in
# 15  hostel_office2 [at] svnit [dot] ac [dot] in
# 16  hostel_office3 [at] svnit [dot] ac [dot] in
# 17  hostel_office4 [at] svnit [dot] ac [dot] in
#                                Name           Contact No.  \
# 1                 Aramya Maheshwari            8951810801
# 2                        Yash Patel            9825114256
# 3                    Neel Majethiya            9033505344
# 4                     Anshika Bhatt            8200276676
# 5                  Abhishek Agarwal            9166110647
# 6                        Pahal Jain            9428923157
# 7                      Shubham Jain            8890072788
# 8                     Nisha Prakash  63556307019558323468
# 9                       Satish Gaur            8980253707
# 10         Dhamecha Jeet Hiteshbhai            9879532120
# 11              Soni Shubham Devang            6355260740
# 12      Shreeji Shaileshkumar Patel            9328603045
# 13  Kapadia Akshaykumar  Rajeshbhai            6355944644
# 14              Vuttur Sharathkumar            8688341233
# 15             Shubham kumar Pandey            7821876465
# 16                 Dhvani Gemlawala            9979404999
# 17                  Nitish Chandaka            8463965288
# 18                    Prasham Sheth            9426426082
# 19                  Pranav Dherange            8460404566
# 20                       Ashi Singh            6353184221
# 21                     Panchal Yash            6354349219
# 22                           Aditya            8432542913
# 23                Dhruv Kumar Kadia            8238072492
# 24                 Akshata Rakesh S            9619032156
# 25                         Sayantan            7586935544
# 26                   Sanket Shahane            8411022496
# 27                           Pankaj  89501872347374891221
# 28              Lingabathina Sravya            9492261672
# 29                      Abdul kadir            9409086935
# 30                 Venkatesh Raja G            9655320364
# 31                      Anand Bhatu            7567689909
# 32           Raghvendra Raghuvanshi            8120658989
# 33                       Alok Araya            9155074550
# 34                        Jash Modi            7874161674
# 35                       Rohit Soni            9370818191
# 36                    Rishabh Sarve            8421409151
# 37              Mustufa Ranapurwala            9427115352
# 38              Swapnil Dilip Patil            8999341004
# 39                   Anjana Vijayan            9995047755
# 40                  Jeet Bhanushali            8888881905
# 41                      Nirav Patel            7405627704
# 42               Yarlagadda Trinath            6281084160
# 43           Sanket Ashish Patadiya            9409766774
# 44                      Kanak Sethi                     -
# 45                   Saurav Prakash  85294576806266039040
# 46                     Aaditya Aman            7061875487
# 47                   Hrithik Mondal            8249294018
#
#                                             E-mail ID
# 1       aramya [dot] maheshwari1 [at] gmail [dot] com
# 2                patelyashmahesh [at] yahoo [dot] com
# 3   neel [dot] b [dot] majethiya [at] gmail [dot] com
# 4               anshikabhatt0207 [at] gmail [dot] com
# 5                 abhishekag2707 [at] gmail [dot] com
# 6                pahaljain002001 [at] gmail [dot] com
# 7                shubhamjain4002 [at] gmail [dot] com
# 8                   nishatnp0063 [at] gmail [dot] com
# 9                  satishgaur407 [at] gmail [dot] com
# 10              mr [dot] jerilim [at] gmail [dot] com
# 11                     sds231101 [at] gmail [dot] com
# 12  shreeji [dot] s [dot] patel12 [at] gmail [dot]...
# 13                   arkkapadiya [at] gmail [dot] com
# 14               vsharathkumar27 [at] gmail [dot] com
# 15           p [dot] shubham1203 [at] gmail [dot] com
# 16               gemlawaladhvani [at] gmail [dot] com
# 17            chandakanitish2209 [at] gmail [dot] com
# 18                prashamsheth38 [at] gmail [dot] com
# 19              pranavdherange07 [at] gmail [dot] com
# 20                  ashi02032001 [at] gmail [dot] com
# 21               panchalyash1000 [at] gmail [dot] com
# 22                2025aditya2002 [at] gmail [dot] com
# 23               dhruvkumarkadia [at] gmail [dot] com
# 24            akshatasirsalewala [at] gmail [dot] com
# 25                 mightysanu123 [at] gmail [dot] com
# 26               sanket98shahane [at] gmail [dot] com
# 27         aryapankaj13 [dot] 13 [at] gmail [dot] com
# 28              sravya [dot] tnp [at] gmail [dot] com
# 29             turbomachines2023 [at] gmail [dot] com
# 30             venkateshraja8123 [at] gmail [dot] com
# 31                  anandbhatu05 [at] gmail [dot] com
# 32       raghuwanshiraghvendra97 [at] gmail [dot] com
# 33                  alokikalok21 [at] gmail [dot] com
# 34                       jashm40 [at] gmail [dot] com
# 35                 sonirohit1407 [at] gmail [dot] com
# 36     rishabhsarve0310 [dot] rs [at] gmail [dot] com
# 37                  ranapurmustu [at] gmail [dot] com
# 38              swapnilpatil3428 [at] gmail [dot] com
# 39                anjanavijayan8 [at] gmail [dot] com
# 40  jeet [dot] p [dot] bhanushali [at] gmail [dot]...
# 41                    niravp9697 [at] gmail [dot] com
# 42           yarlagaddatrinath00 [at] gmail [dot] com
# 43               sanketpatadiya9 [at] gmail [dot] com
# 44                  kanaksethi63 [at] gmail [dot] com
# 45                 sauravsmart19 [at] gmail [dot] com
# 46          adityakumargupta1212 [at] gmail [dot] com
# 47      hrithik [dot] mondal2016 [at] gmail [dot] com
#                                                 Name  \
# 1                                  Shri. R. P. Gohil
# 2                                    Dr. B. N. Gohil
# 3                                 Shri. Dilay Parmar
# 4                                  Dr. Patij K. Shah
# 5                           Sophos Credential issues
# 6  AMC-PC Complaints, AMC-Network Complaints,and ...
# 7                                     Website Upload
# 8                                         CCC Office
#
#                                          Designation  \
# 1           Faculty I/c. C.C.C.& Associate Professor
# 2  Additional FacultyI/c. C.C.C. & Assistant Prof...
# 3                                  Technical Officer
# 4                        Technical Assistant (SG-I))
# 5                                                  -
# 6                                                  -
# 7                                                  -
# 8                                                  -
#
#                                    Contact Details
# 1              ic_ccc [at] svnit [dot] ac [dot] in
# 2          add_ic_ccc [at] svnit [dot] ac [dot] in
# 3  daparmar [at] ccc [dot] svnit [dot] ac [dot] in
# 4                 pks [at] svnit [dot] ac [dot] in
# 5                                     0261-2201567
# 6                                     0261-2201557
# 7                                     0261-2201557
# 8                                     0261-2201568
#                                          Description  \
# 1                                         Women Cell
# 2               Internal Complaints  Committee (ICC)
# 3  OBC Cell Dr. Yogesh D PatilAssociate Professor...
# 4                      Svnit Anti-Ragging  Helpline
# 5                                                NaN
# 6  Dr. Jayesh M. DhodiyaAssociate Professor(Mathe...
# 7         Dr. B. M. SutariaPh. D.Associate Professor
#
#                       Number  \
# 1                          -
# 2                          -
# 3    9998846518 0261-2201624
# 4  0261-2201602,  9157907783
# 5                        NaN
# 6    9825347040 0261-2201785
# 7    9427421615 0261-2201979
#
#                                                Email
# 1             womencell [at] svnit [dot] ac [dot] in
# 2                   icc [at] svnit [dot] ac [dot] in
# 3  obccell [at] svnit [dot] ac [dot] inydp [at] a...
# 4  antiragging_helpline [at] svnit [dot] ac [dot]...
# 5                                                NaN
# 6  scstcell [at] svnit [dot] ac [dot] injmd [at] ...
# 7         bms [at] med [dot] svnit [dot] ac [dot] in

# %% [markdown]
# Thank you.
